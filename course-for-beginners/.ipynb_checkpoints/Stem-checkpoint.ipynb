# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, 7, 1)
y = np.array([2, 2, 6, 7, 3, 8])

plt.stem(x, y, linefmt = ":", markerfmt = "r+", bottom = 4, basefmt = 'green', label="python", orientation="horizontal")
plt.legend(loc="lower right")
plt.show()
